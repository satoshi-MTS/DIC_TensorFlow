# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from keras.datasets import mnist
# %matplotlib inline
import tensorflow.compat.v1 as tf
tf.disable_eager_execution()

# %% [markdown]
# # データの読み込み

# %%
# 読み込み
iris_dataset = load_iris()

# 整形
iris_dataframe = pd.DataFrame(data=iris_dataset.data, columns=iris_dataset.feature_names)
iris_datalabel = pd.DataFrame(data=iris_dataset.target,columns=['Species'])
df = pd.concat([iris_dataframe,iris_datalabel],axis=1)
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      Species
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ..       ...
# 145        2
# 146        2
# 147        2
# 148        2
# 149        2
#
# [150 rows x 5 columns]

# %% [markdown]
# # ミニバッチクラス

# %%
class GetMiniBatch:

    def __init__(self, X, y, batch_size = 10, seed=0):
        self.batch_size = batch_size
        np.random.seed(seed)
        shuffle_index = np.random.permutation(np.arange(X.shape[0]))
        self.X = X[shuffle_index]
        self.y = y[shuffle_index]
        self._stop = np.ceil(X.shape[0]/self.batch_size).astype(np.int)
    def __len__(self):
        return self._stop
    def __getitem__(self,item):
        p0 = item*self.batch_size
        p1 = item*self.batch_size + self.batch_size
        return self.X[p0:p1], self.y[p0:p1]        
    def __iter__(self):
        self._counter = 0
        return self
    def __next__(self):
        if self._counter >= self._stop:
            raise StopIteration()
        p0 = self._counter*self.batch_size
        p1 = self._counter*self.batch_size + self.batch_size
        self._counter += 1
        return self.X[p0:p1], self.y[p0:p1]

# %% [markdown]
# # 問題2　スクラッチとTensorFlowの対応を考える

# %%
# 2値分類のため絞り込み
df2 = df[(df["Species"] == 0)|(df["Species"] == 1)]

# 説明変数と目的変数に分割
y = df2["Species"]
X = df2.loc[:, ["sepal length (cm)", "sepal width (cm)", "petal length (cm)", "petal width (cm)"]]
y = np.array(y)
X = np.array(X)
y = y.astype(np.int)[:, np.newaxis]

# 訓練データ/テストデータ/評価データに分割
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=0)

# 正規化
X_train /= 255
X_test /= 255
X_val /= 255
# Out:
# <ipython-input-4-74baac333f80>:9: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y = y.astype(np.int)[:, np.newaxis]

# %%
# 各種変数定義
learning_rate = 0.01
batch_size = 10
num_epochs = 100
n_hidden1 = 50
n_hidden2 = 100
n_input = X_train.shape[1]
n_samples = X_train.shape[0]
n_classes = 1

# 空配列定義
X = tf.placeholder("float", [None, n_input])
Y = tf.placeholder("float", [None, n_classes])

# ミニバッチイテレータ生成
get_mini_batch_train = GetMiniBatch(X_train, y_train, batch_size=batch_size)

def example_net(x):
    """tensorflowを利用したニューラルネットワーク
    Parameters
    ---------------
    x : 入力配列
    """
    # 重み定義
    weights = {
        'w1': tf.Variable(tf.random_normal([n_input, n_hidden1])),
        'w2': tf.Variable(tf.random_normal([n_hidden1, n_hidden2])),
        'w3': tf.Variable(tf.random_normal([n_hidden2, n_classes]))
    }
    # バイアス定義
    biases = {
        'b1': tf.Variable(tf.random_normal([n_hidden1])),
        'b2': tf.Variable(tf.random_normal([n_hidden2])),
        'b3': tf.Variable(tf.random_normal([n_classes]))
    }
    # 計算グラフ構築（順伝播処理）
    layer_1 = tf.add(tf.matmul(x, weights['w1']), biases['b1'])
    layer_1 = tf.nn.relu(layer_1)
    layer_2 = tf.add(tf.matmul(layer_1, weights['w2']), biases['b2'])
    layer_2 = tf.nn.relu(layer_2)
    layer_output = tf.matmul(layer_2, weights['w3']) + biases['b3']
    return layer_output

# 計算グラフ受け取る
logits = example_net(X)
# 損失定義
loss_op = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(labels=Y, logits=logits))
# 最適化手法の定義
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
# 最適化手法で、定義した損失を最小化するルールを作成
train_op = optimizer.minimize(loss_op)
# ACC計算
correct_pred = tf.equal(tf.sign(Y - 0.5), tf.sign(tf.sigmoid(logits) - 0.5))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# 変数を扱うためのおまじない
init = tf.global_variables_initializer()

# tensorflowのセッション開始
with tf.Session() as sess:
    # 初期化
    sess.run(init)
    # 学習回数分ループ
    for epoch in range(num_epochs):
        # ミニバッチイテレータでループ
        for i, (mini_batch_x, mini_batch_y) in enumerate(get_mini_batch_train):
            # 「最適化手法で、定義した損失を最小化するルール」を実行
            sess.run(train_op, feed_dict={X: mini_batch_x, Y: mini_batch_y})
        # 記録
        train_loss, train_acc = sess.run([loss_op, accuracy], feed_dict={X: X_train, Y: y_train})
        val_loss, val_acc = sess.run([loss_op, accuracy], feed_dict={X: X_val, Y: y_val})
        # 仮定出力
        print("Epoch {}, train_loss : {:.4f}, val_loss : {:.4f}, train_acc : {:.3f}, val_acc : {:.3f}".format(epoch, train_loss, val_loss, train_acc, val_acc))
    
    # 学習が終了したらテストデータで実行
    test_acc = sess.run(accuracy, feed_dict={X: X_test, Y: y_test})
    #prediction = sess.run(logits, feed_dict={X: X_test, Y: y_test})
    #print(prediction)
    print("test_acc : {:.3f}".format(test_acc))
# Out:
# <ipython-input-3-435ce693509b>:9: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   self._stop = np.ceil(X.shape[0]/self.batch_size).astype(np.int)
# Epoch 0, train_loss : 6.1773, val_loss : 8.2309, train_acc : 0.531, val_acc : 0.375
# Epoch 1, train_loss : 1.0906, val_loss : 0.7954, train_acc : 0.469, val_acc : 0.625
# Epoch 2, train_loss : 1.5785, val_loss : 2.0891, train_acc : 0.531, val_acc : 0.375
# Epoch 3, train_loss : 1.8827, val_loss : 1.3168, train_acc : 0.469, val_acc : 0.625
# Epoch 4, train_loss : 0.5971, val_loss : 0.6541, train_acc : 0.531, val_acc : 0.375
# Epoch 5, train_loss : 0.5612, val_loss : 0.5976, train_acc : 0.547, val_acc : 0.438
# Epoch 6, train_loss : 0.7404, val_loss : 0.5565, train_acc : 0.469, val_acc : 0.625
# Epoch 7, train_loss : 0.9409, val_loss : 0.6678, train_acc : 0.469, val_acc : 0.625
# Epoch 8, train_loss : 0.6463, val_loss : 0.4870, train_acc : 0.469, val_acc : 0.625
# Epoch 9, train_loss : 0.5549, val_loss : 0.4322, train_acc : 0.500, val_acc : 0.688
# Epoch 10, train_loss : 0.5853, val_loss : 0.4357, train_acc : 0.469, val_acc : 0.625
# Epoch 11, train_loss : 0.6336, val_loss : 0.4541, train_acc : 0.469, val_acc : 0.625
# Epoch 12, train_loss : 0.6011, val_loss : 0.4282, train_acc : 0.469, val_acc : 0.625
# Epoch 13, train_loss : 0.5297, val_loss : 0.3804, train_acc : 0.531, val_acc : 0.688
# Epoch 14, train_loss : 0.4790, val_loss : 0.3454, train_acc : 0.641, val_acc : 0.875
# Epoch 15, train_loss : 0.4521, val_loss : 0.3237, train_acc : 0.688, val_acc : 0.875
# Epoch 16, train_loss : 0.4313, val_loss : 0.3058, train_acc : 0.734, val_acc : 0.875
# Epoch 17, train_loss : 0.4044, val_loss : 0.2851, train_acc : 0.781, val_acc : 0.875
# Epoch 18, train_loss : 0.3709, val_loss : 0.2614, train_acc : 0.828, val_acc : 0.938
# Epoch 19, train_loss : 0.3365, val_loss : 0.2380, train_acc : 0.906, val_acc : 0.938
# Epoch 20, train_loss : 0.3060, val_loss : 0.2174, train_acc : 0.922, val_acc : 1.000
# Epoch 21, train_loss : 0.2804, val_loss : 0.1999, train_acc : 0.938, val_acc : 1.000
# Epoch 22, train_loss : 0.2582, val_loss : 0.1847, train_acc : 0.953, val_acc : 1.000
# Epoch 23, train_loss : 0.2384, val_loss : 0.1712, train_acc : 0.969, val_acc : 1.000
# Epoch 24, train_loss : 0.2206, val_loss : 0.1592, train_acc : 0.969, val_acc : 1.000
# Epoch 25, train_loss : 0.2048, val_loss : 0.1485, train_acc : 0.984, val_acc : 1.000
# Epoch 26, train_loss : 0.1911, val_loss : 0.1391, train_acc : 0.984, val_acc : 1.000
# Epoch 27, train_loss : 0.1788, val_loss : 0.1307, train_acc : 0.984, val_acc : 1.000
# Epoch 28, train_loss : 0.1680, val_loss : 0.1231, train_acc : 1.000, val_acc : 1.000
# Epoch 29, train_loss : 0.1584, val_loss : 0.1163, train_acc : 1.000, val_acc : 1.000
# Epoch 30, train_loss : 0.1494, val_loss : 0.1101, train_acc : 1.000, val_acc : 1.000
# Epoch 31, train_loss : 0.1415, val_loss : 0.1044, train_acc : 1.000, val_acc : 1.000
# Epoch 32, train_loss : 0.1342, val_loss : 0.0991, train_acc : 1.000, val_acc : 1.000
# Epoch 33, train_loss : 0.1276, val_loss : 0.0943, train_acc : 1.000, val_acc : 1.000
# Epoch 34, train_loss : 0.1213, val_loss : 0.0899, train_acc : 1.000, val_acc : 1.000
# Epoch 35, train_loss : 0.1157, val_loss : 0.0857, train_acc : 1.000, val_acc : 1.000
# Epoch 36, train_loss : 0.1106, val_loss : 0.0818, train_acc : 1.000, val_acc : 1.000
# Epoch 37, train_loss : 0.1055, val_loss : 0.0782, train_acc : 1.000, val_acc : 1.000
# Epoch 38, train_loss : 0.1012, val_loss : 0.0748, train_acc : 1.000, val_acc : 1.000
# Epoch 39, train_loss : 0.0968, val_loss : 0.0716, train_acc : 1.000, val_acc : 1.000
# Epoch 40, train_loss : 0.0930, val_loss : 0.0686, train_acc : 1.000, val_acc : 1.000
# Epoch 41, train_loss : 0.0892, val_loss : 0.0659, train_acc : 1.000, val_acc : 1.000
# Epoch 42, train_loss : 0.0858, val_loss : 0.0632, train_acc : 1.000, val_acc : 1.000
# Epoch 43, train_loss : 0.0825, val_loss : 0.0607, train_acc : 1.000, val_acc : 1.000
# Epoch 44, train_loss : 0.0794, val_loss : 0.0584, train_acc : 1.000, val_acc : 1.000
# Epoch 45, train_loss : 0.0766, val_loss : 0.0561, train_acc : 1.000, val_acc : 1.000
# Epoch 46, train_loss : 0.0738, val_loss : 0.0540, train_acc : 1.000, val_acc : 1.000
# Epoch 47, train_loss : 0.0712, val_loss : 0.0520, train_acc : 1.000, val_acc : 1.000
# Epoch 48, train_loss : 0.0687, val_loss : 0.0501, train_acc : 1.000, val_acc : 1.000
# Epoch 49, train_loss : 0.0664, val_loss : 0.0483, train_acc : 1.000, val_acc : 1.000
# Epoch 50, train_loss : 0.0642, val_loss : 0.0465, train_acc : 1.000, val_acc : 1.000
# Epoch 51, train_loss : 0.0621, val_loss : 0.0449, train_acc : 1.000, val_acc : 1.000
# Epoch 52, train_loss : 0.0601, val_loss : 0.0434, train_acc : 1.000, val_acc : 1.000
# Epoch 53, train_loss : 0.0582, val_loss : 0.0419, train_acc : 1.000, val_acc : 1.000
# Epoch 54, train_loss : 0.0564, val_loss : 0.0405, train_acc : 1.000, val_acc : 1.000
# Epoch 55, train_loss : 0.0546, val_loss : 0.0391, train_acc : 1.000, val_acc : 1.000
# Epoch 56, train_loss : 0.0530, val_loss : 0.0378, train_acc : 1.000, val_acc : 1.000
# Epoch 57, train_loss : 0.0514, val_loss : 0.0366, train_acc : 1.000, val_acc : 1.000
# Epoch 58, train_loss : 0.0499, val_loss : 0.0354, train_acc : 1.000, val_acc : 1.000
# Epoch 59, train_loss : 0.0485, val_loss : 0.0343, train_acc : 1.000, val_acc : 1.000
# Epoch 60, train_loss : 0.0471, val_loss : 0.0332, train_acc : 1.000, val_acc : 1.000
# Epoch 61, train_loss : 0.0458, val_loss : 0.0322, train_acc : 1.000, val_acc : 1.000
# Epoch 62, train_loss : 0.0445, val_loss : 0.0312, train_acc : 1.000, val_acc : 1.000
# Epoch 63, train_loss : 0.0433, val_loss : 0.0303, train_acc : 1.000, val_acc : 1.000
# Epoch 64, train_loss : 0.0421, val_loss : 0.0293, train_acc : 1.000, val_acc : 1.000
# Epoch 65, train_loss : 0.0410, val_loss : 0.0285, train_acc : 1.000, val_acc : 1.000
# Epoch 66, train_loss : 0.0399, val_loss : 0.0276, train_acc : 1.000, val_acc : 1.000
# Epoch 67, train_loss : 0.0389, val_loss : 0.0268, train_acc : 1.000, val_acc : 1.000
# Epoch 68, train_loss : 0.0379, val_loss : 0.0261, train_acc : 1.000, val_acc : 1.000
# Epoch 69, train_loss : 0.0369, val_loss : 0.0253, train_acc : 1.000, val_acc : 1.000
# Epoch 70, train_loss : 0.0360, val_loss : 0.0246, train_acc : 1.000, val_acc : 1.000
# Epoch 71, train_loss : 0.0351, val_loss : 0.0239, train_acc : 1.000, val_acc : 1.000
# Epoch 72, train_loss : 0.0342, val_loss : 0.0233, train_acc : 1.000, val_acc : 1.000
# Epoch 73, train_loss : 0.0334, val_loss : 0.0226, train_acc : 1.000, val_acc : 1.000
# Epoch 74, train_loss : 0.0326, val_loss : 0.0220, train_acc : 1.000, val_acc : 1.000
# Epoch 75, train_loss : 0.0318, val_loss : 0.0214, train_acc : 1.000, val_acc : 1.000
# Epoch 76, train_loss : 0.0311, val_loss : 0.0209, train_acc : 1.000, val_acc : 1.000
# Epoch 77, train_loss : 0.0304, val_loss : 0.0203, train_acc : 1.000, val_acc : 1.000
# Epoch 78, train_loss : 0.0297, val_loss : 0.0198, train_acc : 1.000, val_acc : 1.000
# Epoch 79, train_loss : 0.0290, val_loss : 0.0193, train_acc : 1.000, val_acc : 1.000
# Epoch 80, train_loss : 0.0283, val_loss : 0.0188, train_acc : 1.000, val_acc : 1.000
# Epoch 81, train_loss : 0.0277, val_loss : 0.0183, train_acc : 1.000, val_acc : 1.000
# Epoch 82, train_loss : 0.0271, val_loss : 0.0178, train_acc : 1.000, val_acc : 1.000
# Epoch 83, train_loss : 0.0265, val_loss : 0.0174, train_acc : 1.000, val_acc : 1.000
# Epoch 84, train_loss : 0.0259, val_loss : 0.0170, train_acc : 1.000, val_acc : 1.000
# Epoch 85, train_loss : 0.0254, val_loss : 0.0165, train_acc : 1.000, val_acc : 1.000
# Epoch 86, train_loss : 0.0248, val_loss : 0.0161, train_acc : 1.000, val_acc : 1.000
# Epoch 87, train_loss : 0.0243, val_loss : 0.0158, train_acc : 1.000, val_acc : 1.000
# Epoch 88, train_loss : 0.0238, val_loss : 0.0154, train_acc : 1.000, val_acc : 1.000
# Epoch 89, train_loss : 0.0233, val_loss : 0.0150, train_acc : 1.000, val_acc : 1.000
# Epoch 90, train_loss : 0.0229, val_loss : 0.0147, train_acc : 1.000, val_acc : 1.000
# Epoch 91, train_loss : 0.0224, val_loss : 0.0143, train_acc : 1.000, val_acc : 1.000
# Epoch 92, train_loss : 0.0219, val_loss : 0.0140, train_acc : 1.000, val_acc : 1.000
# Epoch 93, train_loss : 0.0215, val_loss : 0.0137, train_acc : 1.000, val_acc : 1.000
# Epoch 94, train_loss : 0.0211, val_loss : 0.0134, train_acc : 1.000, val_acc : 1.000
# Epoch 95, train_loss : 0.0207, val_loss : 0.0131, train_acc : 1.000, val_acc : 1.000
# Epoch 96, train_loss : 0.0203, val_loss : 0.0128, train_acc : 1.000, val_acc : 1.000
# Epoch 97, train_loss : 0.0199, val_loss : 0.0125, train_acc : 1.000, val_acc : 1.000
# Epoch 98, train_loss : 0.0195, val_loss : 0.0122, train_acc : 1.000, val_acc : 1.000
# Epoch 99, train_loss : 0.0192, val_loss : 0.0119, train_acc : 1.000, val_acc : 1.000
# test_acc : 1.000

# %% [markdown]
# # 問題3　3種類すべての目的変数を使用したIrisのモデルを作成

# %%
# 説明変数と目的変数に分割
y = df["Species"]
X = df.loc[:, ["sepal length (cm)", "sepal width (cm)", "petal length (cm)", "petal width (cm)"]]
y = np.array(y)
X = np.array(X)
y = y.astype(np.int)[:, np.newaxis]

# 訓練データ/テストデータ/評価データに分割
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=0)

# onehotベクトル化
enc = OneHotEncoder(handle_unknown='ignore', sparse=False)
y_train_one_hot = enc.fit_transform(y_train)
y_val_one_hot = enc.transform(y_val)
y_test_one_hot = enc.transform(y_test)

# 正規化
X_train /= 255
X_test /= 255
X_val /= 255
# Out:
# <ipython-input-6-2db749e1cff2>:6: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y = y.astype(np.int)[:, np.newaxis]

# %%
# 各種変数定義
learning_rate = 0.01
batch_size = 10
num_epochs = 100
n_hidden1 = 50
n_hidden2 = 100
n_input = X_train.shape[1]
n_samples = X_train.shape[0]
n_classes = 3 # 2値分類からの変更箇所

# 空配列定義
X = tf.placeholder("float", [None, n_input])
Y = tf.placeholder("float", [None, n_classes])

# ミニバッチイテレータ生成
get_mini_batch_train = GetMiniBatch(X_train, y_train_one_hot, batch_size=batch_size)

def example_net(x):
    """tensorflowを利用したニューラルネットワーク
    Parameters
    ---------------
    x : 入力配列
    """
    # 重み定義
    weights = {
        'w1': tf.Variable(tf.random_normal([n_input, n_hidden1])),
        'w2': tf.Variable(tf.random_normal([n_hidden1, n_hidden2])),
        'w3': tf.Variable(tf.random_normal([n_hidden2, n_classes]))
    }
    # バイアス定義
    biases = {
        'b1': tf.Variable(tf.random_normal([n_hidden1])),
        'b2': tf.Variable(tf.random_normal([n_hidden2])),
        'b3': tf.Variable(tf.random_normal([n_classes]))
    }
    # 計算グラフ構築（順伝播処理）
    layer_1 = tf.add(tf.matmul(x, weights['w1']), biases['b1'])
    layer_1 = tf.nn.relu(layer_1)
    layer_2 = tf.add(tf.matmul(layer_1, weights['w2']), biases['b2'])
    layer_2 = tf.nn.relu(layer_2)
    layer_output = tf.matmul(layer_2, weights['w3']) + biases['b3']
    return layer_output

# 計算グラフ受け取る
logits = example_net(X)
# 損失定義
loss_op = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(labels=Y, logits=logits)) # 2値分類からの変更箇所
# 最適化手法の定義
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
# 最適化手法で、定義した損失を最小化するルールを作成
train_op = optimizer.minimize(loss_op)
# ACC計算
correct_pred = tf.equal(tf.argmax(Y, 1), tf.argmax(logits, 1)) # 2値分類からの変更箇所
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# 変数を扱うためのおまじない
init = tf.global_variables_initializer()

# tensorflowのセッション開始
with tf.Session() as sess:
    # 初期化
    sess.run(init)
    # 学習回数分ループ
    for epoch in range(num_epochs):
        # ミニバッチイテレータでループ
        for i, (mini_batch_x, mini_batch_y) in enumerate(get_mini_batch_train):
            # 「最適化手法で、定義した損失を最小化するルール」を実行
            sess.run(train_op, feed_dict={X: mini_batch_x, Y: mini_batch_y})
        # 記録
        train_loss, train_acc = sess.run([loss_op, accuracy], feed_dict={X: X_train, Y: y_train_one_hot})
        val_loss, val_acc = sess.run([loss_op, accuracy], feed_dict={X: X_val, Y: y_val_one_hot})
        # 仮定出力
        print("Epoch {}, train_loss : {:.4f}, val_loss : {:.4f}, train_acc : {:.3f}, val_acc : {:.3f}".format(epoch, train_loss, val_loss, train_acc, val_acc))
    
    # 学習が終了したらテストデータで実行
    test_acc = sess.run(accuracy, feed_dict={X: X_test, Y: y_test_one_hot})
    #prediction = sess.run(logits, feed_dict={X: X_test, Y: y_test})
    #print(prediction)
    print("test_acc : {:.3f}".format(test_acc))
# Out:
# <ipython-input-3-435ce693509b>:9: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   self._stop = np.ceil(X.shape[0]/self.batch_size).astype(np.int)
# Epoch 0, train_loss : 7.9112, val_loss : 8.0713, train_acc : 0.365, val_acc : 0.375
# Epoch 1, train_loss : 3.8133, val_loss : 3.7940, train_acc : 0.365, val_acc : 0.375
# Epoch 2, train_loss : 2.0767, val_loss : 2.1064, train_acc : 0.365, val_acc : 0.375
# Epoch 3, train_loss : 0.9157, val_loss : 0.8804, train_acc : 0.688, val_acc : 0.708
# Epoch 4, train_loss : 1.4205, val_loss : 1.3213, train_acc : 0.375, val_acc : 0.417
# Epoch 5, train_loss : 0.9955, val_loss : 0.9427, train_acc : 0.688, val_acc : 0.708
# Epoch 6, train_loss : 0.9727, val_loss : 0.9437, train_acc : 0.542, val_acc : 0.625
# Epoch 7, train_loss : 0.8888, val_loss : 0.8624, train_acc : 0.677, val_acc : 0.667
# Epoch 8, train_loss : 0.8057, val_loss : 0.7878, train_acc : 0.594, val_acc : 0.667
# Epoch 9, train_loss : 0.8208, val_loss : 0.8130, train_acc : 0.458, val_acc : 0.375
# Epoch 10, train_loss : 0.8143, val_loss : 0.8077, train_acc : 0.406, val_acc : 0.375
# Epoch 11, train_loss : 0.7844, val_loss : 0.7742, train_acc : 0.583, val_acc : 0.667
# Epoch 12, train_loss : 0.7521, val_loss : 0.7400, train_acc : 0.688, val_acc : 0.667
# Epoch 13, train_loss : 0.7246, val_loss : 0.7134, train_acc : 0.688, val_acc : 0.667
# Epoch 14, train_loss : 0.7028, val_loss : 0.6934, train_acc : 0.708, val_acc : 0.667
# Epoch 15, train_loss : 0.6823, val_loss : 0.6745, train_acc : 0.719, val_acc : 0.708
# Epoch 16, train_loss : 0.6618, val_loss : 0.6558, train_acc : 0.719, val_acc : 0.708
# Epoch 17, train_loss : 0.6425, val_loss : 0.6382, train_acc : 0.740, val_acc : 0.708
# Epoch 18, train_loss : 0.6241, val_loss : 0.6214, train_acc : 0.771, val_acc : 0.708
# Epoch 19, train_loss : 0.6058, val_loss : 0.6043, train_acc : 0.792, val_acc : 0.708
# Epoch 20, train_loss : 0.5878, val_loss : 0.5873, train_acc : 0.833, val_acc : 0.708
# Epoch 21, train_loss : 0.5700, val_loss : 0.5704, train_acc : 0.854, val_acc : 0.792
# Epoch 22, train_loss : 0.5525, val_loss : 0.5537, train_acc : 0.865, val_acc : 0.792
# Epoch 23, train_loss : 0.5354, val_loss : 0.5371, train_acc : 0.865, val_acc : 0.792
# Epoch 24, train_loss : 0.5187, val_loss : 0.5208, train_acc : 0.875, val_acc : 0.833
# Epoch 25, train_loss : 0.5025, val_loss : 0.5049, train_acc : 0.885, val_acc : 0.833
# Epoch 26, train_loss : 0.4868, val_loss : 0.4895, train_acc : 0.896, val_acc : 0.833
# Epoch 27, train_loss : 0.4717, val_loss : 0.4746, train_acc : 0.896, val_acc : 0.833
# Epoch 28, train_loss : 0.4572, val_loss : 0.4603, train_acc : 0.896, val_acc : 0.833
# Epoch 29, train_loss : 0.4434, val_loss : 0.4466, train_acc : 0.927, val_acc : 0.833
# Epoch 30, train_loss : 0.4302, val_loss : 0.4336, train_acc : 0.938, val_acc : 0.875
# Epoch 31, train_loss : 0.4178, val_loss : 0.4212, train_acc : 0.948, val_acc : 0.875
# Epoch 32, train_loss : 0.4060, val_loss : 0.4096, train_acc : 0.948, val_acc : 0.875
# Epoch 33, train_loss : 0.3949, val_loss : 0.3986, train_acc : 0.948, val_acc : 0.875
# Epoch 34, train_loss : 0.3845, val_loss : 0.3883, train_acc : 0.948, val_acc : 0.875
# Epoch 35, train_loss : 0.3747, val_loss : 0.3787, train_acc : 0.948, val_acc : 0.875
# Epoch 36, train_loss : 0.3655, val_loss : 0.3698, train_acc : 0.948, val_acc : 0.875
# Epoch 37, train_loss : 0.3568, val_loss : 0.3613, train_acc : 0.948, val_acc : 0.875
# Epoch 38, train_loss : 0.3486, val_loss : 0.3535, train_acc : 0.948, val_acc : 0.875
# Epoch 39, train_loss : 0.3409, val_loss : 0.3461, train_acc : 0.948, val_acc : 0.875
# Epoch 40, train_loss : 0.3335, val_loss : 0.3393, train_acc : 0.948, val_acc : 0.875
# Epoch 41, train_loss : 0.3265, val_loss : 0.3330, train_acc : 0.948, val_acc : 0.875
# Epoch 42, train_loss : 0.3197, val_loss : 0.3273, train_acc : 0.938, val_acc : 0.917
# Epoch 43, train_loss : 0.3128, val_loss : 0.3222, train_acc : 0.938, val_acc : 0.917
# Epoch 44, train_loss : 0.3059, val_loss : 0.3179, train_acc : 0.948, val_acc : 0.917
# Epoch 45, train_loss : 0.2994, val_loss : 0.3141, train_acc : 0.948, val_acc : 0.875
# Epoch 46, train_loss : 0.2933, val_loss : 0.3105, train_acc : 0.948, val_acc : 0.875
# Epoch 47, train_loss : 0.2876, val_loss : 0.3068, train_acc : 0.948, val_acc : 0.875
# Epoch 48, train_loss : 0.2820, val_loss : 0.3028, train_acc : 0.948, val_acc : 0.875
# Epoch 49, train_loss : 0.2766, val_loss : 0.2988, train_acc : 0.948, val_acc : 0.875
# Epoch 50, train_loss : 0.2713, val_loss : 0.2949, train_acc : 0.948, val_acc : 0.875
# Epoch 51, train_loss : 0.2663, val_loss : 0.2913, train_acc : 0.948, val_acc : 0.875
# Epoch 52, train_loss : 0.2613, val_loss : 0.2879, train_acc : 0.948, val_acc : 0.875
# Epoch 53, train_loss : 0.2565, val_loss : 0.2846, train_acc : 0.948, val_acc : 0.875
# Epoch 54, train_loss : 0.2519, val_loss : 0.2815, train_acc : 0.948, val_acc : 0.875
# Epoch 55, train_loss : 0.2474, val_loss : 0.2784, train_acc : 0.948, val_acc : 0.875
# Epoch 56, train_loss : 0.2430, val_loss : 0.2755, train_acc : 0.948, val_acc : 0.875
# Epoch 57, train_loss : 0.2388, val_loss : 0.2727, train_acc : 0.948, val_acc : 0.875
# Epoch 58, train_loss : 0.2347, val_loss : 0.2700, train_acc : 0.948, val_acc : 0.875
# Epoch 59, train_loss : 0.2307, val_loss : 0.2674, train_acc : 0.948, val_acc : 0.875
# Epoch 60, train_loss : 0.2269, val_loss : 0.2650, train_acc : 0.948, val_acc : 0.875
# Epoch 61, train_loss : 0.2231, val_loss : 0.2626, train_acc : 0.948, val_acc : 0.875
# Epoch 62, train_loss : 0.2195, val_loss : 0.2604, train_acc : 0.948, val_acc : 0.875
# Epoch 63, train_loss : 0.2160, val_loss : 0.2582, train_acc : 0.948, val_acc : 0.875
# Epoch 64, train_loss : 0.2126, val_loss : 0.2561, train_acc : 0.948, val_acc : 0.875
# Epoch 65, train_loss : 0.2094, val_loss : 0.2541, train_acc : 0.948, val_acc : 0.875
# Epoch 66, train_loss : 0.2062, val_loss : 0.2523, train_acc : 0.948, val_acc : 0.875
# Epoch 67, train_loss : 0.2031, val_loss : 0.2504, train_acc : 0.948, val_acc : 0.875
# Epoch 68, train_loss : 0.2001, val_loss : 0.2487, train_acc : 0.948, val_acc : 0.875
# Epoch 69, train_loss : 0.1972, val_loss : 0.2471, train_acc : 0.948, val_acc : 0.875
# Epoch 70, train_loss : 0.1944, val_loss : 0.2455, train_acc : 0.948, val_acc : 0.875
# Epoch 71, train_loss : 0.1917, val_loss : 0.2440, train_acc : 0.948, val_acc : 0.875
# Epoch 72, train_loss : 0.1891, val_loss : 0.2425, train_acc : 0.948, val_acc : 0.875
# Epoch 73, train_loss : 0.1865, val_loss : 0.2412, train_acc : 0.948, val_acc : 0.875
# Epoch 74, train_loss : 0.1841, val_loss : 0.2398, train_acc : 0.948, val_acc : 0.875
# Epoch 75, train_loss : 0.1817, val_loss : 0.2386, train_acc : 0.948, val_acc : 0.875
# Epoch 76, train_loss : 0.1793, val_loss : 0.2374, train_acc : 0.948, val_acc : 0.875
# Epoch 77, train_loss : 0.1771, val_loss : 0.2363, train_acc : 0.948, val_acc : 0.875
# Epoch 78, train_loss : 0.1749, val_loss : 0.2352, train_acc : 0.948, val_acc : 0.875
# Epoch 79, train_loss : 0.1728, val_loss : 0.2342, train_acc : 0.948, val_acc : 0.875
# Epoch 80, train_loss : 0.1707, val_loss : 0.2332, train_acc : 0.948, val_acc : 0.875
# Epoch 81, train_loss : 0.1687, val_loss : 0.2323, train_acc : 0.948, val_acc : 0.875
# Epoch 82, train_loss : 0.1668, val_loss : 0.2314, train_acc : 0.948, val_acc : 0.875
# Epoch 83, train_loss : 0.1649, val_loss : 0.2306, train_acc : 0.948, val_acc : 0.875
# Epoch 84, train_loss : 0.1631, val_loss : 0.2298, train_acc : 0.948, val_acc : 0.875
# Epoch 85, train_loss : 0.1613, val_loss : 0.2291, train_acc : 0.948, val_acc : 0.875
# Epoch 86, train_loss : 0.1596, val_loss : 0.2284, train_acc : 0.948, val_acc : 0.875
# Epoch 87, train_loss : 0.1579, val_loss : 0.2277, train_acc : 0.948, val_acc : 0.875
# Epoch 88, train_loss : 0.1563, val_loss : 0.2271, train_acc : 0.948, val_acc : 0.875
# Epoch 89, train_loss : 0.1547, val_loss : 0.2265, train_acc : 0.948, val_acc : 0.875
# Epoch 90, train_loss : 0.1532, val_loss : 0.2260, train_acc : 0.948, val_acc : 0.875
# Epoch 91, train_loss : 0.1517, val_loss : 0.2255, train_acc : 0.948, val_acc : 0.875
# Epoch 92, train_loss : 0.1502, val_loss : 0.2250, train_acc : 0.948, val_acc : 0.875
# Epoch 93, train_loss : 0.1488, val_loss : 0.2246, train_acc : 0.948, val_acc : 0.875
# Epoch 94, train_loss : 0.1475, val_loss : 0.2242, train_acc : 0.948, val_acc : 0.875
# Epoch 95, train_loss : 0.1461, val_loss : 0.2238, train_acc : 0.948, val_acc : 0.875
# Epoch 96, train_loss : 0.1449, val_loss : 0.2235, train_acc : 0.948, val_acc : 0.875
# Epoch 97, train_loss : 0.1436, val_loss : 0.2231, train_acc : 0.948, val_acc : 0.875
# Epoch 98, train_loss : 0.1424, val_loss : 0.2229, train_acc : 0.948, val_acc : 0.875
# Epoch 99, train_loss : 0.1412, val_loss : 0.2226, train_acc : 0.958, val_acc : 0.875
# test_acc : 0.933

# %% [markdown]
# # 問題4　House Pricesのモデルを作成

# %%
dataset_path ="train.csv"
df = pd.read_csv(dataset_path)

y = df["SalePrice"]
X = df.loc[:, ["GrLivArea", "YearBuilt"]]
y = np.array(y)
X = np.array(X)
y = y.astype(np.int)[:, np.newaxis]
y = np.log(y)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=0)
# Out:
# <ipython-input-14-1c57680061e4>:8: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y = y.astype(np.int)[:, np.newaxis]

# %%
# 各種変数定義
learning_rate = 0.001
batch_size = 10
num_epochs = 10
n_hidden1 = 50
n_hidden2 = 100
n_input = X_train.shape[1]
n_samples = X_train.shape[0]
n_classes = 1

# 空配列定義
X = tf.placeholder("float", [None, n_input])
Y = tf.placeholder("float", [None, n_classes])

# ミニバッチイテレータ生成
get_mini_batch_train = GetMiniBatch(X_train, y_train, batch_size=batch_size)

def example_net(x):
    """tensorflowを利用したニューラルネットワーク
    Parameters
    ---------------
    x : 入力配列
    """
    # 重み定義
    weights = {
        'w1': tf.Variable(tf.random_normal([n_input, n_hidden1])),
        'w2': tf.Variable(tf.random_normal([n_hidden1, n_hidden2])),
        'w3': tf.Variable(tf.random_normal([n_hidden2, n_classes]))
    }
    # バイアス定義
    biases = {
        'b1': tf.Variable(tf.random_normal([n_hidden1])),
        'b2': tf.Variable(tf.random_normal([n_hidden2])),
        'b3': tf.Variable(tf.random_normal([n_classes]))
    }
    # 計算グラフ構築（順伝播処理）
    layer_1 = tf.add(tf.matmul(x, weights['w1']), biases['b1'])
    layer_1 = tf.nn.relu(layer_1)
    layer_2 = tf.add(tf.matmul(layer_1, weights['w2']), biases['b2'])
    layer_2 = tf.nn.relu(layer_2)
    layer_output = tf.matmul(layer_2, weights['w3']) + biases['b3']
    return layer_output

# 計算グラフ受け取る
logits = example_net(X)
# 損失定義
loss_op =  tf.losses.mean_squared_error(labels=Y, predictions=logits)
# 最適化手法の定義
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
# 最適化手法で、定義した損失を最小化するルールを作成
train_op = optimizer.minimize(loss_op)

# 変数を扱うためのおまじない
init = tf.global_variables_initializer()

# tensorflowのセッション開始
with tf.Session() as sess:
    # 初期化
    sess.run(init)
    # 損失記録用リスト
    loss_list = []
    val_loss_list = []
    # 学習回数分ループ
    for epoch in range(num_epochs):
        # ミニバッチイテレータでループ
        for i, (mini_batch_x, mini_batch_y) in enumerate(get_mini_batch_train):
            # 「最適化手法で、定義した損失を最小化するルール」を実行
            sess.run(train_op, feed_dict={X: mini_batch_x, Y: mini_batch_y})
        # 損失計算と格納
        loss = sess.run(loss_op, feed_dict={X: X_train, Y: y_train})
        val_loss = sess.run(loss_op, feed_dict={X: X_val, Y: y_val})
        loss_list.append(loss)
        val_loss_list.append(val_loss)    
        print("Epoch {}, loss : {:.4f}, val_loss : {:.4f}".format(epoch, loss, val_loss))
    
    # 学習過程可視化
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.plot(loss_list, label='loss')
    plt.plot(val_loss_list, label='val_loss')
    plt.legend()
    plt.show()
    # テストデータに適用
    test_loss = sess.run(loss_op, feed_dict={X: X_test, Y: y_test})
    print("test_mse : {:.3f}".format(test_loss))
# Out:
# <ipython-input-3-435ce693509b>:9: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   self._stop = np.ceil(X.shape[0]/self.batch_size).astype(np.int)
# Epoch 0, loss : 4477025.5000, val_loss : 3956218.5000
# Epoch 1, loss : 1222758.8750, val_loss : 1062711.3750
# Epoch 2, loss : 383471.0938, val_loss : 316645.0938
# Epoch 3, loss : 166059.3750, val_loss : 139483.5156
# Epoch 4, loss : 112564.7422, val_loss : 97843.5547
# Epoch 5, loss : 85484.3750, val_loss : 76928.7500
# Epoch 6, loss : 67698.2969, val_loss : 65112.4453
# Epoch 7, loss : 55123.5820, val_loss : 57139.9141
# Epoch 8, loss : 44714.5000, val_loss : 49453.8438
# Epoch 9, loss : 36332.3711, val_loss : 42973.4883
# test_mse : 45036.488

# %% [markdown]
# # 問題5　MNISTのモデルを作成

# %%
# 読み込み
(X_train, y_train), (X_test, y_test) = mnist.load_data()

#　平滑化
X_train = X_train.reshape(-1, 784)
X_test = X_test.reshape(-1, 784)

# 正規化
X_train = X_train.astype(np.float)
X_test = X_test.astype(np.float)
X_train /= 255
X_test /= 255

# 変形
y_train = y_train.astype(np.int)[:, np.newaxis]
y_test = y_test.astype(np.int)[:, np.newaxis]

# one-hotベクトル化
enc = OneHotEncoder(handle_unknown='ignore', sparse=False)
y_train_one_hot = enc.fit_transform(y_train[:])
y_test_one_hot = enc.fit_transform(y_test[:])

# 分割
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train_one_hot, test_size=0.2)
# Out:
# <ipython-input-10-3971c584dfe3>:9: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   X_train = X_train.astype(np.float)
# <ipython-input-10-3971c584dfe3>:10: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   X_test = X_test.astype(np.float)
# <ipython-input-10-3971c584dfe3>:15: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y_train = y_train.astype(np.int)[:, np.newaxis]
# <ipython-input-10-3971c584dfe3>:16: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y_test = y_test.astype(np.int)[:, np.newaxis]

# %%
# 各種変数定義
learning_rate = 0.003
batch_size = 1
num_epochs = 20
n_hidden1 = 50
n_hidden2 = 100
n_input = X_train.shape[1]
n_samples = X_train.shape[0]
n_classes = 10 # 2値分類からの変更箇所

# 空配列定義
X = tf.placeholder("float", [None, n_input])
Y = tf.placeholder("float", [None, n_classes])

# ミニバッチイテレータ生成
get_mini_batch_train = GetMiniBatch(X_train[:1000], y_train[:1000], batch_size=batch_size)

def example_net(x):
    """tensorflowを利用したニューラルネットワーク
    Parameters
    ---------------
    x : 入力配列
    """
    # 重み定義
    weights = {
        'w1': tf.Variable(tf.random_normal([n_input, n_hidden1])),
        'w2': tf.Variable(tf.random_normal([n_hidden1, n_hidden2])),
        'w3': tf.Variable(tf.random_normal([n_hidden2, n_classes]))
    }
    # バイアス定義
    biases = {
        'b1': tf.Variable(tf.random_normal([n_hidden1])),
        'b2': tf.Variable(tf.random_normal([n_hidden2])),
        'b3': tf.Variable(tf.random_normal([n_classes]))
    }
    # 計算グラフ構築（順伝播処理）
    layer_1 = tf.add(tf.matmul(x, weights['w1']), biases['b1'])
    layer_1 = tf.nn.relu(layer_1)
    layer_2 = tf.add(tf.matmul(layer_1, weights['w2']), biases['b2'])
    layer_2 = tf.nn.relu(layer_2)
    layer_output = tf.matmul(layer_2, weights['w3']) + biases['b3']
    return layer_output

# 計算グラフ受け取る
logits = example_net(X)
# 損失定義
loss_op = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(labels=Y, logits=logits)) # 2値分類からの変更箇所
# 最適化手法の定義
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
# 最適化手法で、定義した損失を最小化するルールを作成
train_op = optimizer.minimize(loss_op)
# ACC計算
correct_pred = tf.equal(tf.argmax(Y, 1), tf.argmax(logits, 1)) # 2値分類からの変更箇所
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# 変数を扱うためのおまじない
init = tf.global_variables_initializer()

# tensorflowのセッション開始
with tf.Session() as sess:
    # 初期化
    sess.run(init)
    # 学習回数分ループ
    for epoch in range(num_epochs):
        # ミニバッチイテレータでループ
        for i, (mini_batch_x, mini_batch_y) in enumerate(get_mini_batch_train):
            # 「最適化手法で、定義した損失を最小化するルール」を実行
            sess.run(train_op, feed_dict={X: mini_batch_x, Y: mini_batch_y})
        # 記録
        train_loss, train_acc = sess.run([loss_op, accuracy], feed_dict={X: X_train, Y: y_train})
        val_loss, val_acc = sess.run([loss_op, accuracy], feed_dict={X: X_val, Y: y_val})
        # 仮定出力
        print("Epoch {}, train_loss : {:.4f}, val_loss : {:.4f}, train_acc : {:.3f}, val_acc : {:.3f}".format(epoch, train_loss, val_loss, train_acc, val_acc))
    
    # 学習が終了したらテストデータで実行
    test_acc = sess.run(accuracy, feed_dict={X: X_test, Y: y_test_one_hot})
    #prediction = sess.run(logits, feed_dict={X: X_test, Y: y_test})
    #print(prediction)
    print("test_acc : {:.3f}".format(test_acc))
# Out:
# <ipython-input-3-435ce693509b>:9: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   self._stop = np.ceil(X.shape[0]/self.batch_size).astype(np.int)
# Epoch 0, train_loss : 34.1653, val_loss : 33.6985, train_acc : 0.605, val_acc : 0.604
# Epoch 1, train_loss : 24.6327, val_loss : 24.0912, train_acc : 0.678, val_acc : 0.672
# Epoch 2, train_loss : 20.8009, val_loss : 20.6663, train_acc : 0.693, val_acc : 0.688
# Epoch 3, train_loss : 21.1228, val_loss : 20.8676, train_acc : 0.719, val_acc : 0.720
# Epoch 4, train_loss : 20.5991, val_loss : 20.0395, train_acc : 0.727, val_acc : 0.724
# Epoch 5, train_loss : 21.5066, val_loss : 20.7291, train_acc : 0.734, val_acc : 0.733
# Epoch 6, train_loss : 22.5823, val_loss : 22.7229, train_acc : 0.727, val_acc : 0.723
# Epoch 7, train_loss : 24.3633, val_loss : 23.8900, train_acc : 0.730, val_acc : 0.729
# Epoch 8, train_loss : 20.1899, val_loss : 20.1805, train_acc : 0.770, val_acc : 0.771
# Epoch 9, train_loss : 22.6779, val_loss : 22.4381, train_acc : 0.767, val_acc : 0.765
# Epoch 10, train_loss : 20.8160, val_loss : 20.6431, train_acc : 0.773, val_acc : 0.774
# Epoch 11, train_loss : 19.4738, val_loss : 18.9742, train_acc : 0.785, val_acc : 0.783
# Epoch 12, train_loss : 17.8647, val_loss : 17.3163, train_acc : 0.801, val_acc : 0.796
# Epoch 13, train_loss : 22.5363, val_loss : 22.6793, train_acc : 0.790, val_acc : 0.789
# Epoch 14, train_loss : 23.6145, val_loss : 23.1816, train_acc : 0.773, val_acc : 0.770
# Epoch 15, train_loss : 22.1430, val_loss : 21.7083, train_acc : 0.796, val_acc : 0.794
# Epoch 16, train_loss : 18.6633, val_loss : 18.7615, train_acc : 0.814, val_acc : 0.814
# Epoch 17, train_loss : 21.2896, val_loss : 20.9010, train_acc : 0.810, val_acc : 0.807
# Epoch 18, train_loss : 21.8482, val_loss : 21.2274, train_acc : 0.813, val_acc : 0.811
# Epoch 19, train_loss : 26.2053, val_loss : 25.7291, train_acc : 0.785, val_acc : 0.781
# test_acc : 0.788
